# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({ 'Year': [2020, 2021, 2022, 2023, 2024], 'Sales': [100, 200, 50, 300, 250] })
df
# Out:
#    Year  Sales
# 0  2020    100
# 1  2021    200
# 2  2022     50
# 3  2023    300
# 4  2024    250

# %%
df.plot(x='Year', y='Sales', kind='bar')
plt.show()
